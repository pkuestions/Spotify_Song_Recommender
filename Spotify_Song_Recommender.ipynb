# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import config
import pprint
import pandas as pd
from bs4 import BeautifulSoup
import requests
pd.set_option('display.max_rows', None)
import random

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
results = sp.search(q="Keeno",limit=50,market="DE")

# %% [markdown]
# track_id=results["tracks"]["items"][0]["id"]

# %% [markdown]
# def play_song(track_id):
#     return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
#        width="320",
#        height="80",
#        frameborder="0",
#        allowtransparency="true",
#        allow="encrypted-media",
#       )

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'I Live, I Learn' and the id is: 1hNcVhvZwt1L4eTDWE0D6C
# The name of song is: 'Drowning - Keeno Remix' and the id is: 0Y2TsmyMI2qtTmHL8OCeZt
# The name of song is: 'Keeno' and the id is: 760KfTiPJtsR0qtb1WPLOA
# The name of song is: 'Nocturne' and the id is: 7p6RXRFNp3KgUZmond1ACi
# The name of song is: 'Dancin (feat. Luvli) - Keeno Remix' and the id is: 6s44vnxg18MhaJkpNgcYYT
# The name of song is: 'Faithless' and the id is: 4IgtGuu39vWh47DCybPLXu
# The name of song is: 'Listen Close' and the id is: 6JJGxeTiJNPgPY22Ds6QcR
# The name of song is: 'While The World Sleeps' and the id is: 1ydFbBUaRqLAx3ayIOnW0Y
# The name of song is: 'White Lies - Keeno Remix' and the id is: 2JETMznsLrV7XgGt0BILtd
# The name of song is: 'Communications' and the id is: 3Fai0oHVqe28Tnwp6WxhoU
# The name of song is: 'Never Too Long' and the id is: 3rHGCL5Xa2zUijCaQNDEBN
# The name of song is: 'Shelter From The Storm' and the id is: 5Ina4tWo9cMZ1wXLjALPYx
# The name of song is: 'One More Moment' and the id is: 4xJDnuFIFbOzNxnIY08a5W
# The name of song is: 'Land, Sea and Sky' and the id is: 0lKz06k1SJmOXwxL2HhV2N
# The name of song is: 'Fire Tree' and the id is: 7ypqMUWlkgeP7V8Gvw5Y1k
# The name of song is: 'Cosmic Creeper' and the id is: 2X7saNBUv7RHEGFh9HiHGo
# The name of song is: 'Frozen' and the id is: 0rbYBScEUBlzLA0ar1rTfB
# The name of song is: 'Artificial Skin' and the id is: 1MsFNsKIwmKGCXGzouCetR
# The name of song is: 'Bleary-Eyed' and the id is: 2yJGyMf1BurGMyR4cqKfCX
# The name of song is: 'Futurism' and the id is: 491TxkFmouTdVqwJTY7UG6
# The name of song is: 'Behind The Glass' and the id is: 3Dd0R86fWYsKSk70EhBZ8v
# The name of song is: 'Dignity Found' and the id is: 2G6lrAWzhzwHG0d2xY0Vur
# The name of song is: 'The One True Colour - Keeno Remix' and the id is: 3C0H9vF9RPNKTrIw7ffPCB
# The name of song is: 'Seek & Expand' and the id is: 6cuVOpIDJIuBxLbDFRDB17
# The name of song is: 'Brave Face' and the id is: 0309NnmOZZSmF2OiY9dY9S
# The name of song is: 'Enigma' and the id is: 4BEdYv5U5sCQHIdUkZ4ZPc
# The name of song is: 'Dream Sequence' and the id is: 08S0hXPdew8VPJk2r7kkIv
# The name of song is: 'I Wonder' and the id is: 2ccIGrJHrhdO2uBiQFu1bQ
# The name of song is: 'Keen' and the id is: 3HKKgefffjG5gdPE5Jtcrr
# The name of song is: 'Lost In The Clouds' and the id is: 72ZYFMlVfHzILwYaYNrW9h
# The name of song is: 'Hurricanes (Wild Love) [Keeno Remix]' and the id is: 5r5D35LP1m8bc2YMHF9Gxr
# The name of song is: 'Cosmic Creeper' and the id is: 1MiTwc8yuBwLunJUrkqQ81
# The name of song is: 'Falling' and the id is: 5KbDdGftglbDkFR0bX7qMJ
# The name of song is: 'Communications' and the id is: 3Me5PCBAO2Tx7WKfuHwQKa
# The name of song is: 'Moonrise' and the id is: 0gRQ1wyhS2NoQHGfvmxZW8
# The name of song is: 'At Twilight' and the id is: 3HY6ylAFtE3f5H6kUGCYWi
# The name of song is: 'Guesswork' and the id is: 7KQSgsv89KqOtXianDUqRx
# The name of song is: 'Still Breathing' and the id is: 5m35qCu1rX8LCjLK4QVUqh
# The name of song is: 'Enigma' and the id is: 3aD5k9IvcvfLRg3U84gX3P
# The name of song is: 'My Own Hymn - Keeno Remix' and the id is: 6zNtf1qw3h7ZgCgfgorRuS
# The name of song is: 'Fading Fast' and the id is: 5rIlZ6ixLF6qU9ioJjzq8O
# The name of song is: 'Antiphony' and the id is: 2yqtv5ppqZwmykWLnO8U3z
# The name of song is: 'In The Night - Keeno Remix' and the id is: 2NmsCWMp0SEYKTIK06w7Cy
# The name of song is: 'Better Times Are Coming - Keeno Remix' and the id is: 7HYABKrYzyfar8gSc2TlL9
# The name of song is: 'Love Letter - Keeno Remix' and the id is: 0AhdFp21KyEERp8rx1ALJC
# The name of song is: 'Fall Beneath You' and the id is: 0VzdZGGsJjOZMUHwlZ7uAs
# The name of song is: 'Something (Keeno Remix)' and the id is: 07qZS4tBxJnqiQPtCtFvj1
# The name of song is: 'Out Of Nowhere' and the id is: 3uFuamDwwenwXHd9UuexaN
# The name of song is: 'Insomnia Of An Anxious Mind' and the id is: 4Mxaxkbd5MS6GLqXn8J2yt
# The name of song is: 'Tree Houses' and the id is: 00k6JaeZZxi2OgRReZUn3P

# %% [markdown]
# ## Understanding the json

# %% [markdown]
# print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
# print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
# print("The query we made is: ",results["tracks"]["href"]) # Query we have searched
# print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
# print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
# print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
# print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
# print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
# print("Total number of results: ",results["tracks"]["total"]) # Number of matches

# %% [markdown]
# ## Getting the Audio feature of a song

# %%
sp.audio_features(results["tracks"]["items"][0]["id"] )

# %% [markdown]
# ## Building Data frame of audio features

# %%
#my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

list_of_songs=[]
for index in range(0,len(results["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(results["tracks"]["items"][index]["uri"])[0])
df=pd.DataFrame(list_of_songs)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# 33           0.92300    0.3380   0.1110  173.984  3Me5PCBAO2Tx7WKfuHwQKa
# 34           0.37100    0.1190   0.0759  175.011  0gRQ1wyhS2NoQHGfvmxZW8
# 35           0.83000    0.0710   0.2000  175.025  3HY6ylAFtE3f5H6kUGCYWi
# 36           0.67800    0.1260   0.3840  174.998  7KQSgsv89KqOtXianDUqRx
# 37           0.83500    0.1240   0.0794  175.231  5m35qCu1rX8LCjLK4QVUqh
# 38           0.87600    0.2090   0.0397  175.025  3aD5k9IvcvfLRg3U84gX3P
# 39           0.20300    0.0590   0.0497  174.989  6zNtf1qw3h7ZgCgfgorRuS
# 40           0.79300    0.0862   0.3470  174.988  5rIlZ6ixLF6qU9ioJjzq8O
# 41           0.92500    0.0698   0.1480  172.027  2yqtv5ppqZwmykWLnO8U3z
# 42           0.45900    0.0869   0.3450  174.978  2NmsCWMp0SEYKTIK06w7Cy
# 43           0.00713    0.0867   0.0984  173.963  7HYABKrYzyfar8gSc2TlL9
# 44           0.03180    0.2660   0.2360  173.978  0AhdFp21KyEERp8rx1ALJC
# 45           0.04060    0.0893   0.0377   86.069  0VzdZGGsJjOZMUHwlZ7uAs
# 46           0.51800    0.0737   0.1060  175.030  07qZS4tBxJnqiQPtCtFvj1
# 47           0.77800    0.0853   0.3290  175.096  3uFuamDwwenwXHd9UuexaN
# 48           0.80700    0.0774   0.0354  175.040  4Mxaxkbd5MS6GLqXn8J2yt
# 49           0.86100    0.3220   0.0560  173.981  00k6JaeZZxi2OgRReZUn3P
#
#     duration_ms
# 0        295272
# 1        272492
# 2        136998
# 3        337600
# 4        228947
# 5        285217
# 6        257470
# 7        251891
# 8        265471
# 9        248194
# 10       307300
# 11       251632
# 12       274286
# 13       328004
# 14       130701
# 15       340114
# 16       197631
# 17       345434
# 18       279875
# 19       315190
# 20       308941
# 21       322286
# 22       297242
# 23       330891
# 24       383548
# 25       296406
# 26       402123
# 27       321950
# 28       176203
# 29       224346
# 30       231824
# 31       340114
# 32       356836
# 33       248194
# 34       408686
# 35       250971
# 36       318271
# 37       340214
# 38       296406
# 39       353557
# 40       335376
# 41       232175
# 42       292114
# 43       342069
# 44       259579
# 45       279170
# 46       362057
# 47       269065
# 48       359414
# 49       310445

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "4jQKT5Jj7yFHt1e0huNvLX",market="DE")

# %% [markdown]
# ## List of SPOTIFY Playlists

# %% [markdown]
# ### Source 1

# %%
url_1 = "https://audiohype.io/resources/the-best-spotify-playlists/"
response_1 = requests.get(url_1)
print(response_1.status_code) # 200 status code means OK!
soup_1 = BeautifulSoup(response_1.content, "html.parser")

playlists_list_1 = [soup_1.select(".rank-math-link")[pl]["href"].split("?")[0] 
                    for pl in range(len(soup_1.select(".rank-math-link")))]
playlists_list_1 = [url.split("/")[-1] for url in playlists_list_1][:-1]
print(f"List of {len(playlists_list_1)} playlists has been created!")
# Out:
# 200
# List of 28 playlists has been created!

# %% [markdown]
# ### Source 2

# %%
url_2 = "https://www.noteburner.com/spotify-music-tips/top-10-spotify-playlist.html"
response_2 = requests.get(url_2)
print(response_2.status_code) # 200 status code means OK!
soup_2 = BeautifulSoup(response_2.content, "html.parser")

playlists_list_2 = [soup_2.select("div.contaienr > div > div > ul > li > a")[pl]["href"].split("?")[0] 
                    for pl in range(len(soup_2.select("div.contaienr > div > div > ul > li > a")))]
playlists_list_2 = [url.split("/")[-1] for url in playlists_list_2][:-1]
print(f"List of {len(playlists_list_2)} playlists has been created!")
# Out:
# 200
# List of 9 playlists has been created!

# %% [markdown]
# ### Create complete list of all playlists_lists

# %%
playlists_list = []
playlists_list.extend(playlists_list_1)
playlists_list.extend(playlists_list_2)
print(f"Total number of playlist IDs is {len(playlists_list)}")
# Out:
# Total number of playlist IDs is 37

# %% [markdown]
# ## Playlist functions

# %% [markdown]
# ### Extracting `<TRACKS>`

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %% [markdown]
# ### Extracting song `<IDs>`

# %%
def get_playlist_track_ids(playlist):
    song_ids_list = [playlist[id]["track"]["id"] for id in range(len(playlist))]
    return song_ids_list

#song_ids_list = get_playlist_track_ids(playlist)

# %% [markdown]
# ### Extracting song `<NAMES>`

# %%
def get_playlist_track_names(playlist):
    song_names_list = [playlist[t]["track"]["name"] for t in range(len(playlist))]
    return song_names_list

#song_names_list = get_playlist_track_names(playlist)

# %% [markdown]
# ### Extracting song `<ARTISTS>`

# %%
def get_playlist_track_artists(playlist):
    song_artist_list = [playlist[artist]["track"]["artists"][0]["name"] for artist in range(len(playlist))]
    return song_artist_list

#song_artist_list = get_playlist_track_artists(playlist)

# %% [markdown]
# ### Extracting song `<AUDIO FEATURES>`

# %%
def get_playlist_track_audiofeatures(id_list):
    
    audio_features_list = []
    
    if len(song_ids_list) > 100:
        lower_bound_iterables = list(range(0, len(song_ids_list), 100))
        upper_bound_iterables = list(range(100, len(song_ids_list), 100))
        upper_bound_iterables.append(len(song_ids_list))
    
        for idx, bound in enumerate(lower_bound_iterables):
            song_audiofeatures_list = sp.audio_features(song_ids_list[lower_bound_iterables[idx]:upper_bound_iterables[idx]])
            audio_features_list.extend(song_audiofeatures_list)
    
    else:
        audio_features_list = sp.audio_features(song_ids_list)
    return audio_features_list

#song_audiofeatures_list = get_playlist_track_audiofeatures(song_ids_list)

# %% [markdown]
# ## Create dataframe with song `<NAMEs>`, `<ARTISTs>`, `<IDs>`, `<AUDIO FEATUREs>`

# %%
def create_df_to_concat_to_base():

    df_1 = pd.DataFrame(data={
        "song_name": song_names_list,
        "song_artist": song_artist_list,
    })

    df_2 = pd.DataFrame(song_audiofeatures_list)    
    df_2 = df_2[["id","danceability","energy","loudness","speechiness","acousticness",
               "instrumentalness","liveness","valence","tempo","duration_ms"]]

    df = pd.concat([df_1, df_2], axis=1)
    print(f"Dataframe with {len(df)} entries was created as `df_to_concat`")
    return df

#df = create_df_to_concat_to_base()

# %% [markdown]
# ## Extend csv with dataframe to concat

# %%
def extend_collection():
    
    df_base = pd.read_csv("Song_Collection_Extended.csv")
    df_extended = pd.concat([df_base, df], axis=0, ignore_index=True)
    df_extended.to_csv("Song_Collection_Extended.csv", index=False)
    print(f"Extended base dataframe (length = {len(df_base)}) by {len(df)} songs!")
    return df_extended

#df_extended = extend_collection()

# %% [markdown]
# ## PIPELINE - Looping through list of playlists

# %%
playlists_list
# Out:
# ['37i9dQZF1DXcBWIGoYBM5M',
#  '31ymdYCITDnZRtkKzP3Itp',
#  '0cc8YMQWsSzODyTpdVB6mI',
#  '37i9dQZF1DX5hHfOi73rY3',
#  '37i9dQZF1DXa71eg5j9dKZ',
#  '4kw9kdjzx1UmyWvpysl0y2',
#  '1xNWydoMmA8210KeHU948w',
#  '6vDGVr652ztNWKZuHvsFvx',
#  '6J1r02xyO2qkMA9dDNZytJ',
#  '5wtqmpRl17iVz2nW8U6njL',
#  '0NCspsyf0OS4BsPgGhkQXM',
#  '19y0UVk0bcrJWEqMwBHosj',
#  '4oOZJEq1TBUti6PSouTo5M',
#  '068WHS0zOWsqvn2uIBYb5D',
#  '6ZTpgxK6BT92mmsqwETj9l',
#  '37i9dQZF1DWSvKsRPPnv5o',
#  '37i9dQZF1DXe4Cw8IKKIvr',
#  '37i9dQZF1DXcDoDDetPsEg',
#  '65xSncKQzG6Suseh5gfYP1',
#  '0MSCX9tZWQmitMQsfhvZIl',
#  '1PmwMQY86pJuAm7veFt3u2',
#  '6wjCvkAFovrVIRM8VfZLZG',
#  '37i9dQZF1DWVV27DiNWxkR',
#  '37i9dQZF1DWVzZlRWgqAGH',
#  '37i9dQZF1DXc8kgYqQLMfH',
#  '31FWVQBp3WQydWLNhO0ACi',
#  '37i9dQZF1DXa9wYJr1oMFq',
#  '37i9dQZF1DX8FwnYE6PRvL']

# %%
for idx, plist in enumerate(playlists_list):

    playlist=get_playlist_tracks("spotify", plist)
    song_ids_list = get_playlist_track_ids(playlist)
    song_names_list = get_playlist_track_names(playlist)
    song_artist_list = get_playlist_track_artists(playlist)
    song_audiofeatures_list = get_playlist_track_audiofeatures(song_ids_list)
    df = create_df_to_concat_to_base()
    df_extended = extend_collection()
# Out:
# Dataframe with 50 entries was created as `df_to_concat`
# Extended base dataframe (length = 2060) by 50 songs!
# Dataframe with 100 entries was created as `df_to_concat`
# Extended base dataframe (length = 2110) by 100 songs!
# Dataframe with 50 entries was created as `df_to_concat`
# Extended base dataframe (length = 2210) by 50 songs!
# Dataframe with 50 entries was created as `df_to_concat`
# Extended base dataframe (length = 2260) by 50 songs!
# Dataframe with 129 entries was created as `df_to_concat`
# Extended base dataframe (length = 2310) by 129 songs!
# Dataframe with 60 entries was created as `df_to_concat`
# Extended base dataframe (length = 2439) by 60 songs!
# Dataframe with 39 entries was created as `df_to_concat`
# Extended base dataframe (length = 2499) by 39 songs!
# Dataframe with 90 entries was created as `df_to_concat`
# Extended base dataframe (length = 2538) by 90 songs!
# Dataframe with 60 entries was created as `df_to_concat`
# Extended base dataframe (length = 2628) by 60 songs!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
#       1 for idx, plist in enumerate(playlists_list):
#       3     playlist=get_playlist_tracks("spotify", plist)
# ----> 4     song_ids_list = get_playlist_track_ids(playlist)
#       5     song_names_list = get_playlist_track_names(playlist)
#       6     song_artist_list = get_playlist_track_artists(playlist)
#
# Input In [6], in get_playlist_track_ids(playlist)
#       1 def get_playlist_track_ids(playlist):
# ----> 2     song_ids_list = [playlist[id]["track"]["id"] for id in range(len(playlist))]
#       3     return song_ids_list
#
# Input In [6], in <listcomp>(.0)
#       1 def get_playlist_track_ids(playlist):
# ----> 2     song_ids_list = [playlist[id]["track"]["id"] for id in range(len(playlist))]
#       3     return song_ids_list
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# df_base = pd.read_csv("Song_Collection_2.csv")

# %% [markdown]
# df_extended = pd.concat([df_base, df], axis=0, ignore_index=True)
# df_extended.to_csv("Song_Collection_3.csv")

# %%
df_extended
# Out:
#               song_name    song_artist                      id  danceability  \
# 0         Say Something      Grayscale  6NGeSE3jQRV2we50n6Qv2A         0.486
# 1      Domestic Dispute  Sink The Ship  0bWW617I0LB12t6gXFsCoo         0.348
# 2           She's A God      Neck Deep  3rmVrevtGa5y7wieirt7rZ         0.603
# 3        Our Time to Go   State Champs  29VZaw57nwUtKeGBVv1n9K         0.256
# 4             Lightning   State Champs  2f23wbpcWh5jW6GFK3FPjN         0.424
# ..                  ...            ...                     ...           ...
# 270               Draco           BCee  5dlEb6A6LxmO9qVtBzjr0v         0.491
# 271     Close Your Eyes      Wilkinson  3WpZaVBGjVgR7lxekzkXTY         0.457
# 272            Sunshine           BCee  1VoGmQaWfpfw0mcAvKUYaM         0.653
# 273        Here For You      Wilkinson  1QgebV92VO4Z7VxbQ1tSKo         0.358
# 274  Stay - Maduk Remix          Maduk  585g0eS2FU9uXlqBEaP1mZ         0.460
#
#      energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0     0.938    -3.896       0.0411      0.002290          0.000003    0.3390
# 1     0.955    -3.954       0.1000      0.000311          0.000000    0.0890
# 2     0.956    -3.997       0.1120      0.030400          0.000000    0.4240
# 3     0.892    -3.360       0.0519      0.010300          0.000000    0.0801
# 4     0.968    -2.815       0.0929      0.000106          0.000020    0.0685
# ..      ...       ...          ...           ...               ...       ...
# 270   0.866    -3.553       0.0357      0.007810          0.403000    0.1230
# 271   0.918    -2.893       0.0626      0.158000          0.046400    0.1020
# 272   0.869    -4.761       0.0664      0.000599          0.176000    0.0942
# 273   0.780    -3.400       0.0447      0.175000          0.000620    0.2650
# 274   0.914    -3.856       0.0388      0.001890          0.206000    0.0728
#
#      valence    tempo  duration_ms
# 0     0.7280  130.103       213317
# 1     0.2800  159.940       219373
# 2     0.3370  121.043       200331
# 3     0.6020  168.172       224111
# 4     0.7580  195.092       176402
# ..       ...      ...          ...
# 270   0.2310  172.073       297309
# 271   0.0369  173.965       284138
# 272   0.5640  174.007       312191
# 273   0.0402  173.917       226207
# 274   0.1860  174.992       205714
#
# [1432 rows x 13 columns]

# %% [markdown]
# df_base = pd.read_csv("Song_Collection.csv")
